# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6892 0.3868 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6405 0.3676 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5215 0.3650 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5839 0.3710 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5111 0.3767 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5259 0.3539 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5497 0.3373 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5817 0.3433 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4537 0.3449 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4285 0.3400 sec/batch
# Nearest to about: merlin, embryogenesis, dysfunction, specialises, nicea, edoardo, consecutively, madrigals,
# Nearest to be: hellenic, generally, forbes, deception, switches, fastball, stovl, smaller,
# Nearest to been: deco, rubbed, hj, assigned, flavors, cordilleras, teosinte, refuges,
# Nearest to d: shoreditch, unearthly, foxy, gaines, hairless, paschal, harvester, lectronique,
# Nearest to may: orchard, maury, arm, truro, felipe, matisse, bleeding, dollfu,
# Nearest to into: sales, boomerang, embryology, cystitis, mcfowl, lair, laird, buzzing,
# Nearest to used: hlich, willey, biol, exteriors, eurostar, otto, lippe, shrink,
# Nearest to such: shaffer, forage, prospecting, salus, placements, undergrowth, ontogeny, hindering,
# Nearest to police: seven, populate, harboring, alumina, jawaharlal, stagg, chatroom, collaborate,
# Nearest to discovered: evangelion, stubbs, magnetometer, cairns, argonautica, playing, aided, jericho,
# Nearest to brother: dimebag, spends, orinoco, regressive, coldplay, sanitation, sterilized, housework,
# Nearest to mathematics: dfts, macro, bloomberg, seconda, abhidhamma, blender, factional, eliot,
# Nearest to hold: tinkering, tai, shrieks, goldoni, emotive, clos, davao, prizren,
# Nearest to square: jail, barlaam, chloroplasts, writers, regicide, keywords, mme, glacially,
# Nearest to additional: catabolic, bandai, jonesboro, edirne, teleological, racine, hide, breastfeeding,
# Nearest to bbc: ghat, dugan, niobids, byzantines, tripolitania, temperature, darya, poverty,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4829 0.3413 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3894 0.3432 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3284 0.3452 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2351 0.3683 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1599 0.3798 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1183 0.3581 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0820 0.3684 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0504 0.3416 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9813 0.3308 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9600 0.3301 sec/batch
# Nearest to about: nicea, tools, charlotte, started, notes, considered, continuing, dysfunction,
# Nearest to be: hellenic, non, smaller, stored, continuing, generally, crash, makes,
# Nearest to been: assigned, rubbed, low, hj, unique, complicated, albums, teosinte,
# Nearest to d: unearthly, shoreditch, foxy, harvester, gaines, lectronique, pensions, surgeons,
# Nearest to may: arm, orchard, interpreted, betty, experience, bleeding, felipe, adults,
# Nearest to into: sales, illegal, south, embryology, part, first, boomerang, cystitis,
# Nearest to used: high, class, otto, shrink, turns, dispatched, improved, hlich,
# Nearest to such: placements, signal, hne, intrinsic, hindering, beverly, shaffer, prospecting,
# Nearest to police: seven, populate, toronto, harboring, collaborate, net, stagg, financial,
# Nearest to discovered: playing, cairns, aided, solo, evangelion, stubbs, contended, routinely,
# Nearest to brother: dimebag, spends, regressive, sterilized, obedience, sanitation, coldplay, orinoco,
# Nearest to mathematics: macro, blender, dfts, frank, eliot, bloomberg, june, bug,
# Nearest to hold: tai, tinkering, clos, descendant, emotive, value, downstream, butterflies,
# Nearest to square: jail, writers, makes, sharp, barlaam, shall, regicide, culturally,
# Nearest to additional: properties, couples, libyan, catabolic, wave, hide, any, company,
# Nearest to bbc: temperature, poverty, last, psychologists, ghat, byzantines, dugan, tripolitania,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9224 0.3294 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8900 0.3328 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8838 0.3238 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8606 0.3447 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8245 0.3399 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8142 0.3652 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8178 0.5581 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7946 0.3864 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7790 0.3889 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7629 0.3757 sec/batch
# Nearest to about: nicea, merlin, dysfunction, continuing, started, memorandum, consecutively, edoardo,
# Nearest to be: hellenic, smaller, non, presumed, continuing, stored, deception, makes,
# Nearest to been: assigned, rubbed, deco, hj, flavors, albums, shadow, priests,
# Nearest to d: pensions, harvester, shoreditch, lectronique, unearthly, approximated, composer, scientist,
# Nearest to may: orchard, arm, charming, bleeding, felipe, places, ferraris, betty,
# Nearest to into: sales, illegal, south, embryology, part, mcfowl, temperance, boomerang,
# Nearest to used: high, class, misinterpreted, otto, shrink, dispatched, biol, hlich,
# Nearest to such: placements, intrinsic, shaffer, salus, chapel, prospecting, hilbert, signal,
# Nearest to police: seven, populate, harboring, collaborate, jawaharlal, alpine, losses, vat,
# Nearest to discovered: evangelion, playing, aided, solo, cairns, magnetometer, contended, lever,
# Nearest to brother: spends, dimebag, obedience, sterilized, regressive, companion, defeated, managers,
# Nearest to mathematics: macro, eliot, dfts, dick, ever, frank, bug, defines,
# Nearest to hold: tinkering, vols, descendant, tai, clos, atmosphere, cheque, emotive,
# Nearest to square: jail, makes, julian, writers, sharp, keywords, regicide, shall,
# Nearest to additional: properties, couples, libyan, hide, catabolic, wave, any, pledges,
# Nearest to bbc: poverty, psychologists, temperature, last, byzantines, ghat, dugan, scroll,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7582 0.3447 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7641 0.3499 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7239 0.3598 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7181 0.3481 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7294 0.3614 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6785 0.3606 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7230 0.3754 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6821 0.3954 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6986 0.3756 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6529 0.3726 sec/batch
# Nearest to about: nicea, merlin, dysfunction, consecutively, memorandum, continuing, pharisee, stimulate,
# Nearest to be: hellenic, non, presumed, smaller, continuing, deception, stored, generally,
# Nearest to been: deco, assigned, rubbed, hj, flavors, duel, priests, cordilleras,
# Nearest to d: composer, scientist, chronicon, yasser, shoreditch, paschal, harvester, pensions,
# Nearest to may: orchard, arm, bleeding, places, maury, charming, truro, felipe,
# Nearest to into: illegal, sales, part, embryology, south, mcfowl, laird, temperance,
# Nearest to used: high, misinterpreted, shrink, biol, light, hlich, harsanyi, bard,
# Nearest to such: shaffer, placements, intrinsic, signal, hilbert, hindering, wdc, salus,
# Nearest to police: seven, jawaharlal, populate, vat, collaborate, toronto, alumina, tarmac,
# Nearest to discovered: evangelion, lever, aided, magnetometer, contended, playing, solo, cairns,
# Nearest to brother: spends, dimebag, obedience, regressive, companion, iberian, sterilized, miko,
# Nearest to mathematics: macro, eliot, dfts, factional, alarming, blender, bug, ever,
# Nearest to hold: tinkering, tai, clos, vols, discrepancy, shrieks, descendant, inquisition,
# Nearest to square: jail, makes, lorien, writers, keywords, barlaam, tremblay, irreducibly,
# Nearest to additional: catabolic, properties, wave, libyan, couples, hide, teleological, pulaski,
# Nearest to bbc: ghat, psychologists, poverty, last, byzantines, dugan, tippit, obrzeg,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6820 0.4144 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6712 4.8308 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6287 0.4134 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6486 0.3844 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.5970 0.3559 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6397 0.3822 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6153 0.2549 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5536 0.3941 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5347 0.3641 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5075 0.3573 sec/batch
# Nearest to about: merlin, nicea, dysfunction, embryogenesis, started, specialises, edoardo, consecutively,
# Nearest to be: hellenic, non, presumed, smaller, deception, stored, basic, continuing,
# Nearest to been: deco, assigned, flavors, fairytale, priests, gnome, duel, limerick,
# Nearest to d: composer, scientist, b, chemist, actress, writer, chronicon, nine,
# Nearest to may: orchard, arm, places, charming, bleeding, maury, truro, dollfu,
# Nearest to into: illegal, embryology, sales, mcfowl, with, part, receiver, temperance,
# Nearest to used: high, improved, light, provide, shrink, ssi, convert, misinterpreted,
# Nearest to such: intrinsic, placements, shaffer, signal, diverging, salus, prospecting, hilbert,
# Nearest to police: jawaharlal, seven, collaborate, populate, vat, chatroom, tarmac, bidders,
# Nearest to discovered: evangelion, lever, aided, magnetometer, cairns, uniformitarianism, taliban, contended,
# Nearest to brother: dimebag, spends, regressive, obedience, iberian, defeated, miko, sadr,
# Nearest to mathematics: macro, eliot, dfts, alarming, factional, neopaganism, simplifications, loeb,
# Nearest to hold: tinkering, clos, tai, shrieks, discrepancy, descendant, inquisition, onshore,
# Nearest to square: jail, tremblay, lorien, makes, barlaam, irreducibly, sharp, keywords,
# Nearest to additional: properties, catabolic, wave, hide, couples, jonesboro, libyan, edirne,
# Nearest to bbc: ghat, tippit, last, dugan, byzantines, psychologists, poverty, obrzeg,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4957 0.3935 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5196 0.3908 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4697 0.3981 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5179 0.3461 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4993 0.3556 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4438 0.3681 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4554 0.3790 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4029 0.3803 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4014 0.4170 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4334 0.4140 sec/batch
# Nearest to about: merlin, nicea, dysfunction, edoardo, specialises, embryogenesis, stimulate, started,
# Nearest to be: hellenic, non, stored, basic, makes, presumed, deception, fastball,
# Nearest to been: deco, flavors, assigned, priests, fairytale, cordilleras, gnome, limerick,
# Nearest to d: composer, chronicon, scientist, chemist, yasser, b, actress, paschal,
# Nearest to may: orchard, bleeding, delineate, stakeholder, tenderness, solutions, arm, segments,
# Nearest to into: illegal, with, embryology, sales, part, euphemistic, temperance, receiver,
# Nearest to used: high, improved, convert, light, shrink, provide, class, biol,
# Nearest to such: intrinsic, signal, are, placements, diverging, wdc, salus, prospecting,
# Nearest to police: jawaharlal, seven, collaborate, chatroom, vat, populate, spiro, bidders,
# Nearest to discovered: evangelion, lever, aided, magnetometer, uniformitarianism, taliban, cairns, hamdan,
# Nearest to brother: dimebag, spends, regressive, obedience, iberian, defeated, sadr, companion,
# Nearest to mathematics: macro, dfts, eliot, simplifications, neopaganism, loeb, factional, alarming,
# Nearest to hold: tinkering, clos, shrieks, tai, descendant, prizren, discrepancy, gis,
# Nearest to square: jail, sq, tremblay, paved, barlaam, coordinates, lorien, makes,
# Nearest to additional: properties, catabolic, wave, jonesboro, hide, couples, edirne, bandai,
# Nearest to bbc: ghat, tippit, dugan, last, psychologists, poverty, obrzeg, byzantines,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4393 0.4088 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4406 0.4093 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4406 0.4188 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3856 0.4332 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4212 0.4585 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4278 0.4325 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4120 0.4001 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3767 0.4579 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4191 0.4291 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.4084 0.4347 sec/batch
# Nearest to about: merlin, nicea, edoardo, embryogenesis, dysfunction, constantinian, memorandum, uninformed,
# Nearest to be: hellenic, non, presumed, stored, fastball, makes, basic, without,
# Nearest to been: deco, flavors, assigned, priests, mandrakesoft, spock, mitochondrial, excommunications,
# Nearest to d: composer, chronicon, scientist, b, lectronique, chemist, fran, alexandra,
# Nearest to may: orchard, delineate, stakeholder, bleeding, arm, places, bounce, quartic,
# Nearest to into: illegal, south, part, embryology, naturally, sales, with, uniform,
# Nearest to used: improved, high, light, class, shrink, convert, provide, trademarked,
# Nearest to such: intrinsic, are, diverging, shaffer, placements, signal, wdc, kinderhook,
# Nearest to police: jawaharlal, collaborate, harboring, seat, losses, pusan, vat, seven,
# Nearest to discovered: evangelion, uniformitarianism, aided, lever, taliban, magnetometer, bourne, protectress,
# Nearest to brother: dimebag, regressive, spends, iberian, obedience, sadr, companion, miko,
# Nearest to mathematics: macro, dfts, eliot, defines, neopaganism, husserl, practical, disk,
# Nearest to hold: tinkering, clos, tai, asking, value, shrieks, gis, prizren,
# Nearest to square: sq, jail, coordinates, tremblay, lorien, paved, barlaam, chloroplasts,
# Nearest to additional: properties, catabolic, wave, edirne, couples, jonesboro, bandai, hide,
# Nearest to bbc: ghat, tippit, dugan, last, obrzeg, gardnerian, psychologists, athene,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3760 0.4250 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3686 0.4234 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3506 0.3923 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3757 0.4052 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3952 0.3919 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3678 0.3828 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3739 0.3894 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3765 0.3790 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3523 0.3918 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3424 0.3961 sec/batch
# Nearest to about: merlin, edoardo, nicea, dysfunction, embryogenesis, uninformed, erp, pharisee,
# Nearest to be: hellenic, non, without, presumed, stored, makes, unmodified, vivo,
# Nearest to been: deco, flavors, assigned, priests, matsushita, magnetometer, excommunications, spock,
# Nearest to d: composer, scientist, chronicon, b, lectronique, fran, chemist, harvester,
# Nearest to may: orchard, bleeding, delineate, places, truro, dollfu, stakeholder, veishea,
# Nearest to into: illegal, embryology, south, part, naturally, with, temperance, eastwards,
# Nearest to used: convert, improved, shrink, trademarked, class, light, molded, high,
# Nearest to such: are, intrinsic, diverging, wdc, shaffer, salus, placements, prospecting,
# Nearest to police: jawaharlal, collaborate, losses, vat, seven, harboring, blowout, spiro,
# Nearest to discovered: uniformitarianism, evangelion, magnetometer, lever, aided, skipped, taliban, hamdan,
# Nearest to brother: dimebag, spends, regressive, iberian, companion, obedience, sadr, she,
# Nearest to mathematics: eliot, defines, husserl, dfts, neopaganism, macro, symbiosis, simplifications,
# Nearest to hold: tinkering, prizren, asking, clos, goldoni, regret, policies, shrieks,
# Nearest to square: sq, coordinates, jail, tremblay, sharp, rainfall, lorien, barlaam,
# Nearest to additional: catabolic, edirne, properties, jonesboro, couples, wave, bandai, sculpting,
# Nearest to bbc: ghat, tippit, dugan, last, obrzeg, peckinpah, gardnerian, athene,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3479 0.4119 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3153 0.3889 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3859 0.3782 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3878 0.4097 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3902 0.4855 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2984 0.3805 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2914 0.3540 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3501 0.3797 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2288 1.4611 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2840 8.9903 sec/batch
# Nearest to about: edoardo, nicea, merlin, uninformed, dysfunction, embryogenesis, constantinian, memorandum,
# Nearest to be: hellenic, presumed, non, unmodified, vivo, basic, without, stored,
# Nearest to been: deco, flavors, excommunications, assigned, magnetometer, spock, eschews, matsushita,
# Nearest to d: composer, b, scientist, chemist, fran, chronicon, actress, lectronique,
# Nearest to may: orchard, places, dollfu, delineate, truro, bleeding, matisse, mujahideen,
# Nearest to into: illegal, south, embryology, part, with, eastwards, communicates, euphemistic,
# Nearest to used: convert, extruded, shrink, light, molded, trademarked, improved, provide,
# Nearest to such: intrinsic, are, shaffer, diverging, placements, reasons, salus, wdc,
# Nearest to police: jawaharlal, collaborate, acquitted, losses, interceptors, spiro, blowout, presidential,
# Nearest to discovered: uniformitarianism, evangelion, magnetometer, aided, lever, taliban, bourne, skipped,
# Nearest to brother: dimebag, spends, regressive, sadr, iberian, she, himmler, companion,
# Nearest to mathematics: husserl, eliot, defines, macro, dfts, practical, neopaganism, simplifications,
# Nearest to hold: tinkering, goldoni, value, asking, prizren, regret, tai, shrieks,
# Nearest to square: sq, coordinates, tremblay, jail, glacially, sharp, lorien, barlaam,
# Nearest to additional: catabolic, edirne, jonesboro, properties, couples, wave, sculpting, officio,
# Nearest to bbc: ghat, tippit, last, dugan, peckinpah, gardnerian, obrzeg, klimt,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3207 41.7051 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2929 0.3486 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3414 0.1970 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2421 0.3430 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2100 0.4228 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2171 0.3278 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2104 0.3498 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2002 0.3479 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2200 0.3644 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1961 0.3875 sec/batch
# Nearest to about: uninformed, nicea, embryogenesis, edoardo, merlin, constantinian, segregation, dysfunction,
# Nearest to be: hellenic, presumed, non, unmodified, without, deception, argument, vivo,
# Nearest to been: deco, flavors, excommunications, spock, eschews, magnetometer, priests, matsushita,
# Nearest to d: composer, b, scientist, chemist, chronicon, fran, lectronique, actress,
# Nearest to may: orchard, dollfu, places, bleeding, matisse, truro, mujahideen, quartic,
# Nearest to into: illegal, south, embryology, part, with, eastwards, receiver, euphemistic,
# Nearest to used: improved, extruded, convert, trademarked, shrink, exteriors, molded, class,
# Nearest to such: diverging, are, intrinsic, salus, wdc, placements, reasons, shaffer,
# Nearest to police: jawaharlal, acquitted, interceptors, collaborate, losses, harboring, jts, vat,
# Nearest to discovered: uniformitarianism, magnetometer, evangelion, taliban, aided, lever, skipped, protectress,
# Nearest to brother: dimebag, sadr, iberian, regressive, miko, himmler, spends, him,
# Nearest to mathematics: eliot, husserl, defines, macro, loeb, practical, gaussian, alarming,
# Nearest to hold: tinkering, goldoni, value, tai, prizren, asking, oxfam, shrieks,
# Nearest to square: sq, coordinates, tremblay, regular, barlaam, sharp, lorien, glacially,
# Nearest to additional: catabolic, jonesboro, edirne, properties, couples, racine, amassed, officio,
# Nearest to bbc: ghat, tippit, last, dugan, peckinpah, gardnerian, psychologists, athene,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2362 0.4269 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2661 0.3836 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2344 0.3829 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1407 0.3959 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2039 0.4025 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1632 0.4054 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1658 0.4118 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1922 0.3947 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1893 0.3859 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1778 0.3840 sec/batch
# Nearest to about: embryogenesis, uninformed, merlin, nicea, edoardo, erp, dysfunction, confine,
# Nearest to be: hellenic, presumed, stored, unmodified, without, cannot, non, makes,
# Nearest to been: flavors, deco, excommunications, priests, magnetometer, eschews, spock, assigned,
# Nearest to d: composer, b, chronicon, scientist, chemist, asymptotically, lectronique, fran,
# Nearest to may: orchard, dollfu, delineate, places, bleeding, helical, matisse, quartic,
# Nearest to into: illegal, south, part, embryology, hatti, euphemistic, uniform, communicates,
# Nearest to used: trademarked, molded, convert, class, extruded, improved, shrink, ssi,
# Nearest to such: are, intrinsic, diverging, wdc, placements, eszterh, change, salus,
# Nearest to police: jawaharlal, interceptors, acquitted, collaborate, harboring, losses, jts, spiro,
# Nearest to discovered: uniformitarianism, magnetometer, lever, evangelion, taliban, protectress, hamdan, bourne,
# Nearest to brother: dimebag, housework, iberian, sadr, espy, regressive, sepulveda, himmler,
# Nearest to mathematics: husserl, eliot, defines, gaussian, mathematicians, gauss, loeb, practical,
# Nearest to hold: tinkering, value, tai, goldoni, clos, asking, prizren, discrepancy,
# Nearest to square: sq, coordinates, tremblay, regular, lies, barlaam, sharp, glacially,
# Nearest to additional: catabolic, jonesboro, edirne, properties, officio, couples, sculpting, repetitive,
# Nearest to bbc: ghat, tippit, dugan, last, peckinpah, interacted, suse, gardnerian,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1725 0.4215 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2613 0.4156 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1645 0.3913 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1698 0.3882 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1851 0.3877 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1915 0.3934 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2063 0.3946 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1501 0.3883 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1401 0.3902 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1797 0.3950 sec/batch
# Nearest to about: uninformed, embryogenesis, merlin, erp, edoardo, dysfunction, nicea, pharisee,
# Nearest to be: hellenic, presumed, unmodified, non, stored, boulton, without, makes,
# Nearest to been: flavors, deco, excommunications, priests, magnetometer, limerick, ghettos, eschews,
# Nearest to d: composer, b, scientist, chemist, chronicon, fran, apollinaire, lectronique,
# Nearest to may: orchard, delineate, places, gametes, matisse, helical, dollfu, bleeding,
# Nearest to into: illegal, part, south, embryology, uniform, receiver, telephony, lighthearted,
# Nearest to used: trademarked, class, convert, molded, extruded, improved, exteriors, ssi,
# Nearest to such: are, intrinsic, diverging, wdc, shaffer, salus, amperes, eszterh,
# Nearest to police: jawaharlal, interceptors, acquitted, harboring, collaborate, jts, blowout, bidders,
# Nearest to discovered: uniformitarianism, magnetometer, evangelion, lever, hamdan, moebius, moth, protectress,
# Nearest to brother: dimebag, housework, spends, iberian, she, companion, sepulveda, lady,
# Nearest to mathematics: husserl, eliot, defines, mathematicians, practical, gaussian, euclid, loeb,
# Nearest to hold: tinkering, value, asking, goldoni, tai, clos, discrepancy, prizren,
# Nearest to square: sq, coordinates, tremblay, regular, louder, glacially, sharp, lies,
# Nearest to additional: catabolic, jonesboro, edirne, officio, properties, sculpting, amassed, couples,
# Nearest to bbc: ghat, tippit, dugan, last, peckinpah, interacted, timid, emigrating,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1854 0.3792 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1890 0.3928 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1897 0.3961 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1933 0.3596 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1377 0.3631 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1373 0.3707 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1906 0.3586 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1037 0.3669 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1910 0.3761 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1966 0.3712 sec/batch
# Nearest to about: memorandum, merlin, uninformed, nicea, pharisee, myles, edoardo, mend,
# Nearest to be: hellenic, presumed, suffrage, unmodified, without, non, boulton, xxxi,
# Nearest to been: excommunications, deco, flavors, spock, eschews, priests, croat, magnetometer,
# Nearest to d: composer, b, scientist, chemist, fran, apollinaire, chronicon, sculptor,
# Nearest to may: orchard, places, delineate, matisse, rhetorically, restated, dollfu, mujahideen,
# Nearest to into: illegal, part, south, embryology, eastwards, hatti, euphemistic, lighthearted,
# Nearest to used: convert, molded, class, trademarked, extruded, willey, exteriors, cuisine,
# Nearest to such: intrinsic, diverging, wdc, are, salus, shaffer, eszterh, placements,
# Nearest to police: jawaharlal, acquitted, interceptors, collaborate, harboring, blowout, spiro, jordanian,
# Nearest to discovered: uniformitarianism, magnetometer, evangelion, protectress, fathers, moebius, lever, taliban,
# Nearest to brother: spends, dimebag, she, housework, companion, himmler, iberian, sepulveda,
# Nearest to mathematics: husserl, eliot, mathematicians, euclid, loeb, gauss, clausius, practical,
# Nearest to hold: tinkering, goldoni, tai, value, prizren, asking, regret, clos,
# Nearest to square: sq, coordinates, tremblay, regular, lies, louder, jail, glacially,
# Nearest to additional: catabolic, jonesboro, edirne, officio, amassed, sculpting, edition, lzw,
# Nearest to bbc: ghat, tippit, dugan, last, peckinpah, timid, emigrating, englishes,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2250 0.3683 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1138 0.3661 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1438 0.3710 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1431 0.3720 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0396 0.3672 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1565 0.3637 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1422 0.3644 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1505 0.3574 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1919 0.0867 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1047 0.4032 sec/batch
# Nearest to about: uninformed, embryogenesis, pharisee, mend, erp, myles, edoardo, flora,
# Nearest to be: hellenic, presumed, unmodified, stored, without, logistic, non, cannot,
# Nearest to been: flavors, excommunications, deco, eschews, spock, magnetometer, croat, priests,
# Nearest to d: composer, b, scientist, chemist, fran, apollinaire, lectronique, chronicon,
# Nearest to may: orchard, places, delineate, mujahideen, rhetorically, gametes, matisse, dollfu,
# Nearest to into: illegal, part, south, telephony, embryology, eastwards, hatti, magnifying,
# Nearest to used: convert, basten, extruded, molded, trademarked, class, willey, exteriors,
# Nearest to such: are, intrinsic, diverging, embarrass, wdc, shaffer, salus, ontogeny,
# Nearest to police: jawaharlal, interceptors, acquitted, harboring, collaborate, jts, spiro, jordanian,
# Nearest to discovered: uniformitarianism, magnetometer, protectress, moebius, moth, lever, taliban, logarithmic,
# Nearest to brother: himmler, spends, dimebag, she, housework, sepulveda, iberian, companion,
# Nearest to mathematics: husserl, eliot, loeb, euclid, alarming, clausius, mathematicians, simplifications,
# Nearest to hold: tinkering, goldoni, tai, clos, value, regret, blogs, discrepancy,
# Nearest to square: sq, coordinates, regular, tremblay, glacially, jail, sharp, birding,
# Nearest to additional: edirne, catabolic, officio, jonesboro, amassed, lzw, edition, eez,
# Nearest to bbc: ghat, tippit, dugan, last, interacted, june, peckinpah, emigrating,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0708 0.4060 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0862 36.3369 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0976 72.5714 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0564 72.7752 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0626 26.2360 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0357 98.0602 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0953 72.7300 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1076 10.1352 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1236 0.3941 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0589 0.3866 sec/batch
# Nearest to about: uninformed, erp, california, census, mend, prematurely, flora, july,
# Nearest to be: hellenic, presumed, smaller, unmodified, broth, without, makes, stored,
# Nearest to been: deco, flavors, excommunications, priests, barlaam, croat, spock, eschews,
# Nearest to d: composer, b, scientist, chemist, apollinaire, fran, asymptotically, chronicon,
# Nearest to may: orchard, places, delineate, rhetorically, of, risk, treatable, gametes,
# Nearest to into: south, illegal, part, first, singly, hatti, eastwards, telephony,
# Nearest to used: convert, basten, molded, class, extruded, trademarked, willey, improved,
# Nearest to such: are, diverging, intrinsic, embarrass, salus, wdc, eszterh, shaffer,
# Nearest to police: jawaharlal, interceptors, acquitted, harboring, collaborate, prisoners, spiro, jts,
# Nearest to discovered: uniformitarianism, magnetometer, protectress, lever, moth, moebius, hypnos, logarithmic,
# Nearest to brother: spends, dimebag, housework, himmler, sepulveda, iberian, tefan, she,
# Nearest to mathematics: husserl, eliot, alarming, loeb, clausius, euclid, practical, mathematicians,
# Nearest to hold: tinkering, tai, clos, goldoni, blogs, value, prizren, oxfam,
# Nearest to square: sq, coordinates, jail, regular, tremblay, glacially, hotels, norfolk,
# Nearest to additional: catabolic, jonesboro, edirne, officio, edition, lzw, amassed, repetitive,
# Nearest to bbc: ghat, last, tippit, interacted, dugan, peckinpah, june, faqs,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0470 0.3829 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0434 0.3553 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0050 0.3741 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0421 0.3717 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0955 0.3490 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0601 0.3804 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0560 0.4948 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1046 0.4034 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0583 0.3958 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0236 0.4281 sec/batch
# Nearest to about: uninformed, mend, merlin, myles, erp, legume, confine, california,
# Nearest to be: presumed, unmodified, hellenic, cannot, broth, makes, logistic, stored,
# Nearest to been: excommunications, flavors, deco, croat, spock, magnetometer, priests, coleoptera,
# Nearest to d: composer, b, scientist, asymptotically, chemist, apollinaire, lectronique, fran,
# Nearest to may: orchard, places, delineate, gametes, which, iau, restated, treatable,
# Nearest to into: south, part, illegal, first, singly, telephony, swap, electrodes,
# Nearest to used: class, convert, basten, molded, extruded, trademarked, usage, exteriors,
# Nearest to such: are, diverging, intrinsic, amperes, wdc, these, increasingly, shaffer,
# Nearest to police: interceptors, jawaharlal, acquitted, harboring, collaborate, spiro, prisoners, jts,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, logarithmic, moebius, moth, lever, hypnos,
# Nearest to brother: spends, housework, dimebag, she, iberian, himmler, sepulveda, companion,
# Nearest to mathematics: husserl, eliot, alarming, euclid, clausius, loeb, gauss, studying,
# Nearest to hold: tinkering, tai, clos, blogs, goldoni, prizren, oxfam, regret,
# Nearest to square: sq, coordinates, jail, neighbourhoods, regular, tremblay, louder, birding,
# Nearest to additional: catabolic, jonesboro, edirne, officio, sculpting, arian, stresses, edition,
# Nearest to bbc: ghat, tippit, interacted, dugan, peckinpah, last, june, timid,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0483 0.3718 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0949 0.3633 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1094 0.3314 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0460 0.3309 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0941 0.3329 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0602 0.3353 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0801 0.3336 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0533 0.3401 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0865 0.3540 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0569 0.3411 sec/batch
# Nearest to about: mend, uninformed, flora, merlin, pharisee, nicea, myles, july,
# Nearest to be: hellenic, presumed, unmodified, suffrage, smaller, broth, moshiach, stored,
# Nearest to been: excommunications, flavors, croat, deco, priests, indications, barlaam, ghettos,
# Nearest to d: composer, b, scientist, lectronique, apollinaire, asymptotically, harvester, alexandra,
# Nearest to may: orchard, places, delineate, rhetorically, mujahideen, ninth, which, initiates,
# Nearest to into: south, part, illegal, eastwards, first, hatti, yew, bergamo,
# Nearest to used: convert, class, basten, usage, molded, trademarked, invented, extruded,
# Nearest to such: are, diverging, shaffer, wdc, increasingly, intrinsic, amperes, overlapping,
# Nearest to police: interceptors, jawaharlal, harboring, acquitted, spiro, prisoners, collaborate, crime,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, moebius, moth, logarithmic, hypnos, cramps,
# Nearest to brother: spends, she, housework, iberian, himmler, dimebag, duke, sepulveda,
# Nearest to mathematics: husserl, eliot, alarming, loeb, clausius, euclid, studying, supervised,
# Nearest to hold: tinkering, tai, blogs, clos, goldoni, prizren, regret, oxfam,
# Nearest to square: sq, coordinates, jail, neighbourhoods, tuples, louder, myung, birding,
# Nearest to additional: jonesboro, officio, catabolic, edirne, amassed, sculpting, lzw, stresses,
# Nearest to bbc: ghat, tippit, dugan, peckinpah, interacted, last, gant, englishes,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0454 0.3441 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0159 0.3358 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0259 0.3411 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0443 0.3812 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0764 0.3814 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1296 0.3633 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1367 0.3338 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0432 0.3293 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0661 0.3296 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0714 0.3400 sec/batch
# Nearest to about: july, mend, census, flora, myles, pharisee, erp, california,
# Nearest to be: unmodified, hellenic, presumed, cannot, smaller, suffrage, logistic, stored,
# Nearest to been: excommunications, deco, flavors, indications, spock, matsushita, croat, mitochondrial,
# Nearest to d: composer, b, scientist, apollinaire, lectronique, chemist, inge, harvester,
# Nearest to may: orchard, places, delineate, rhetorically, initiates, iau, matisse, mujahideen,
# Nearest to into: part, south, first, illegal, eastwards, uprisings, articulations, hatti,
# Nearest to used: usage, convert, basten, molded, class, extruded, otto, provide,
# Nearest to such: are, diverging, embarrass, overlapping, shaffer, intrinsic, edm, these,
# Nearest to police: interceptors, jawaharlal, harboring, spiro, acquitted, crimes, blowout, collaborate,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, moebius, hypnos, cramps, moth, logarithmic,
# Nearest to brother: she, spends, himmler, dimebag, appian, anoint, tefan, housework,
# Nearest to mathematics: husserl, eliot, alarming, clausius, euclid, studying, loeb, mathematicians,
# Nearest to hold: tinkering, tai, blogs, clos, goldoni, shrieks, oxfam, regret,
# Nearest to square: sq, coordinates, jail, birding, louder, regular, neighbourhoods, jharkhand,
# Nearest to additional: jonesboro, officio, catabolic, edirne, sculpting, stresses, libyan, amassed,
# Nearest to bbc: ghat, tippit, peckinpah, june, last, englishes, dugan, emigrating,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9695 0.3500 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0363 0.3376 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0441 0.3452 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0379 0.3406 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0902 0.3464 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0264 0.3485 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0017 0.3555 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9771 0.3462 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0224 0.3387 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9808 0.3422 sec/batch
# Nearest to about: july, mend, flora, census, myles, uninformed, california, erp,
# Nearest to be: presumed, hellenic, unmodified, cannot, suffrage, moshiach, smaller, without,
# Nearest to been: excommunications, deco, flavors, indications, eschews, cary, spock, barlaam,
# Nearest to d: composer, b, scientist, apollinaire, fran, inge, chemist, alexandra,
# Nearest to may: orchard, places, rhetorically, iau, gametes, treatable, normally, delineate,
# Nearest to into: part, south, first, eastwards, telephony, communicates, electrodes, articulations,
# Nearest to used: basten, convert, usage, molded, cysts, rifles, provide, cuisine,
# Nearest to such: are, diverging, diagnosing, embarrass, these, evolve, hunmin, edm,
# Nearest to police: interceptors, jawaharlal, acquitted, harboring, crime, spiro, crimes, lakeview,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, moebius, moth, logarithmic, hypnos, clear,
# Nearest to brother: she, spends, himmler, cousin, tefan, married, conte, sepulveda,
# Nearest to mathematics: husserl, eliot, alarming, loeb, euclid, clausius, mathematicians, supervised,
# Nearest to hold: tinkering, tai, blogs, clos, goldoni, shrieks, compromising, prizren,
# Nearest to square: sq, coordinates, jail, birding, neighbourhoods, jharkhand, louder, glacially,
# Nearest to additional: officio, jonesboro, catabolic, stresses, edition, edirne, keyed, repetitive,
# Nearest to bbc: ghat, june, englishes, tippit, emigrating, day, timid, last,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0129 0.3438 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9530 0.3432 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0350 0.3581 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0188 0.3545 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0446 0.3524 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0132 0.3501 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9003 0.3451 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9719 0.3449 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9513 0.3423 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9757 0.3655 sec/batch
# Nearest to about: uninformed, july, erp, flora, mend, census, california, vcrs,
# Nearest to be: unmodified, cannot, hellenic, smaller, suffrage, without, presumed, dimer,
# Nearest to been: excommunications, deco, indications, flavors, has, croat, mitochondrial, occurring,
# Nearest to d: composer, b, apollinaire, lectronique, scientist, alexandra, asymptotically, suvorov,
# Nearest to may: orchard, places, iau, delineate, treatable, normally, initiates, risk,
# Nearest to into: part, south, first, telephony, bivalent, communicates, illegal, hatti,
# Nearest to used: basten, convert, usage, uses, molded, cysts, interceptor, rifles,
# Nearest to such: are, diagnosing, diverging, edm, intrinsic, hunmin, cosmetic, also,
# Nearest to police: interceptors, jawaharlal, harboring, acquitted, spiro, crime, lakeview, collaborate,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, moebius, moth, logarithmic, hypnos, missions,
# Nearest to brother: conte, spends, she, sepulveda, housework, dimebag, appian, himmler,
# Nearest to mathematics: husserl, eliot, loeb, alarming, mathematicians, clausius, euclid, supervised,
# Nearest to hold: tinkering, blogs, clos, tai, stacked, goldoni, bent, oxfam,
# Nearest to square: sq, coordinates, jail, neighbourhoods, birding, jharkhand, regular, glacially,
# Nearest to additional: officio, catabolic, jonesboro, libyan, stresses, arian, edition, edirne,
# Nearest to bbc: ghat, tippit, june, interacted, englishes, timid, emigrating, peckinpah,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9792 0.3798 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0203 0.3649 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9755 0.3617 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9823 0.3678 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0481 0.3804 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9638 0.3685 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9800 0.3836 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9970 0.3889 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0008 0.3939 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9987 0.4233 sec/batch
# Nearest to about: erp, july, disturbs, mend, uninformed, pacino, started, california,
# Nearest to be: unmodified, cannot, without, hellenic, presumed, a, suffrage, smaller,
# Nearest to been: excommunications, flavors, indications, mitochondrial, croat, deco, albums, barlaam,
# Nearest to d: composer, b, apollinaire, lectronique, fran, alexandra, scientist, inge,
# Nearest to may: orchard, places, normally, delineate, iau, initiates, rhetorically, treatable,
# Nearest to into: part, south, first, telephony, communicates, embryology, auxin, receiver,
# Nearest to used: usage, uses, class, convert, basten, invented, molded, tivo,
# Nearest to such: are, amperes, hunmin, intrinsic, edm, these, diagnosing, diverging,
# Nearest to police: interceptors, jawaharlal, harboring, acquitted, spiro, crime, lakeview, pusan,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, moebius, moth, logarithmic, clear, hypnos,
# Nearest to brother: she, housework, spends, conte, sepulveda, dimebag, appian, anoint,
# Nearest to mathematics: husserl, eliot, euclid, alarming, loeb, clausius, mathematicians, gauss,
# Nearest to hold: tinkering, clos, blogs, bent, goldoni, hyped, compromising, stacked,
# Nearest to square: sq, jail, coordinates, birding, neighbourhoods, louder, myung, tuples,
# Nearest to additional: officio, jonesboro, catabolic, edition, stresses, libyan, repetitive, sculpting,
# Nearest to bbc: ghat, tippit, timid, saturday, interacted, dvb, englishes, peckinpah,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9848 0.3875 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9895 0.3839 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9848 0.3996 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9935 0.3902 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0255 0.3831 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0013 0.3924 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9852 0.3847 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9651 0.3852 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9421 0.3872 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0310 0.3934 sec/batch
# Nearest to about: july, erp, flora, census, disturbs, mend, uninformed, started,
# Nearest to be: unmodified, hellenic, suffrage, cannot, without, presumed, smaller, unauthorized,
# Nearest to been: excommunications, flavors, indications, has, deco, croat, partnered, barlaam,
# Nearest to d: composer, b, apollinaire, fran, alexandra, lectronique, inge, scientist,
# Nearest to may: orchard, places, rhetorically, initiates, ninth, normally, iau, mujahideen,
# Nearest to into: part, first, south, telephony, eastwards, lessens, peninsular, yew,
# Nearest to used: usage, convert, uses, basten, provide, invented, molded, tivo,
# Nearest to such: are, amperes, these, edm, also, dini, cosmetic, wdc,
# Nearest to police: interceptors, jawaharlal, harboring, spiro, lakeview, crime, acquitted, fong,
# Nearest to discovered: uniformitarianism, protectress, magnetometer, logarithmic, clear, moebius, missions, moth,
# Nearest to brother: she, spends, sepulveda, conte, appian, sister, housework, anoint,
# Nearest to mathematics: husserl, mathematicians, euclid, loeb, eliot, alarming, clausius, kummer,
# Nearest to hold: tinkering, blogs, clos, hyped, goldoni, bent, regret, tai,
# Nearest to square: sq, coordinates, jail, neighbourhoods, birding, jharkhand, myung, louder,
# ...
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8185 0.3595 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8895 0.3736 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9102 0.3752 sec/batch
# Nearest to about: disturbs, length, census, driest, july, hipparchus, viewer, started,
# Nearest to be: that, a, which, smaller, is, to, this, cannot,
# Nearest to been: has, had, apg, most, suggested, eschews, although, flavors,
# Nearest to d: b, composer, keenan, biggs, fran, inge, sydenham, suvorov,
# Nearest to may: or, of, initiates, every, they, be, iau, as,
# Nearest to into: first, the, through, which, part, to, auxin, absorb,
# Nearest to used: usage, refer, invented, or, uses, roman, as, which,
# Nearest to such: are, these, also, all, many, webpages, even, or,
# Nearest to police: lakeview, crime, interceptors, loria, witness, extradited, superpowered, haven,
# Nearest to discovered: uniformitarianism, logarithmic, clear, piccard, cramps, protectress, found, moebius,
# Nearest to brother: sister, sepulveda, anoint, spends, conte, mszp, sturm, daughter,
# Nearest to mathematics: mathematicians, loeb, kummer, husserl, supervised, calculations, euclid, alarming,
# Nearest to hold: socks, tinkering, bent, hyped, stacked, compromising, ridged, clos,
# Nearest to square: sq, jharkhand, jail, malmesbury, louder, coordinates, face, myung,
# Nearest to additional: repetitive, stresses, sculpting, catabolic, functionally, canceled, printings, duodenal,
# Nearest to bbc: links, day, skit, june, saturday, holidays, aired, external,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8466 0.3790 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8736 0.3531 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8503 0.3417 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8453 0.3634 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8612 0.3953 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8856 0.3816 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8726 0.3848 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8487 0.3862 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8763 0.3926 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8820 0.4380 sec/batch
# Nearest to about: disturbs, census, driest, length, july, hipparchus, myles, started,
# Nearest to be: that, a, smaller, which, as, given, is, cannot,
# Nearest to been: has, had, most, apg, sympathies, eschews, suggested, surviving,
# Nearest to d: b, composer, keenan, biggs, fran, foxy, roxanne, inge,
# Nearest to may: of, or, initiates, every, be, iau, they, no,
# Nearest to into: first, the, through, to, part, of, which, south,
# Nearest to used: refer, usage, invented, uses, or, as, purposes, roman,
# Nearest to such: these, are, also, all, tartar, many, as, even,
# Nearest to police: lakeview, crime, interceptors, loria, witness, superpowered, case, extradited,
# Nearest to discovered: uniformitarianism, logarithmic, found, piccard, cramps, clear, bombarding, protectress,
# Nearest to brother: sister, sepulveda, spends, mszp, anoint, daughter, son, married,
# Nearest to mathematics: mathematicians, kummer, loeb, supervised, euclid, pasternak, husserl, honorum,
# Nearest to hold: socks, tinkering, bent, hyped, compromising, stacked, prescott, ridged,
# Nearest to square: sq, jharkhand, jail, malmesbury, greeted, coordinates, myung, louder,
# Nearest to additional: repetitive, stresses, canceled, sculpting, libyan, printings, similar, couples,
# Nearest to bbc: links, day, skit, interviewer, holidays, saturday, aired, interacted,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8463 0.4153 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8319 0.3825 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8222 0.3852 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8138 0.3881 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9066 0.3653 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8599 0.3527 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9479 0.3636 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8883 0.3474 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9078 0.3382 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7931 0.3438 sec/batch
# Nearest to about: length, people, driest, disturbs, july, census, started, pacino,
# Nearest to be: that, which, cannot, a, smaller, is, given, without,
# Nearest to been: has, had, most, sympathies, apg, although, unfolded, eschews,
# Nearest to d: b, composer, fran, keenan, chronicon, suvorov, roxanne, biggs,
# Nearest to may: or, every, initiates, of, they, iau, ibu, normally,
# Nearest to into: the, first, through, which, part, to, south, of,
# Nearest to used: usage, refer, or, invented, uses, purposes, as, roman,
# Nearest to such: also, are, these, tartar, all, many, as, even,
# Nearest to police: lakeview, crime, witness, interceptors, loria, extradited, cardozo, murders,
# Nearest to discovered: uniformitarianism, logarithmic, piccard, found, clear, cramps, bombarding, entertained,
# Nearest to brother: sister, sepulveda, spends, mszp, anoint, sturm, son, daughter,
# Nearest to mathematics: mathematicians, kummer, loeb, euclid, calculus, sindh, abhidhamma, supervised,
# Nearest to hold: tinkering, socks, bent, hyped, prescott, compromising, reisman, blogs,
# Nearest to square: sq, malmesbury, jharkhand, jail, louder, greeted, coordinates, myung,
# Nearest to additional: repetitive, stresses, libyan, canceled, jiao, functionally, printings, sculpting,
# Nearest to bbc: links, day, skit, june, external, interviewer, saturday, peckinpah,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7937 0.3453 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8571 0.3332 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8060 0.3400 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8802 0.3364 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8194 0.3321 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8616 0.3512 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8560 0.2428 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8349 0.3538 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8215 0.3568 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8677 0.3568 sec/batch
# Nearest to about: length, july, driest, census, disturbs, started, hipparchus, people,
# Nearest to be: that, as, which, a, smaller, is, cannot, was,
# Nearest to been: has, had, most, although, eschews, suggested, though, apg,
# Nearest to d: b, composer, keenan, fran, biggs, suvorov, roxanne, menuhin,
# Nearest to may: or, of, every, initiates, can, iau, zoster, they,
# Nearest to into: the, first, through, which, to, part, south, absorb,
# Nearest to used: usage, refer, purposes, uses, invented, is, as, roman,
# Nearest to such: these, are, also, tartar, as, all, many, which,
# Nearest to police: crime, lakeview, witness, extradited, loria, interceptors, criminal, cardozo,
# Nearest to discovered: uniformitarianism, piccard, found, bombarding, logarithmic, cramps, clear, protectress,
# Nearest to brother: sister, sepulveda, anoint, mszp, spends, sturm, conte, housework,
# Nearest to mathematics: mathematicians, loeb, kummer, calculus, mathematical, phd, alarming, euclid,
# Nearest to hold: tinkering, socks, bent, hyped, prescott, fateh, stacked, compromising,
# Nearest to square: sq, malmesbury, jharkhand, louder, coordinates, jail, greeted, myung,
# Nearest to additional: repetitive, stresses, canceled, functionally, jiao, sculpting, libyan, printings,
# Nearest to bbc: links, day, external, june, skit, holidays, ghat, sek,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8015 0.3652 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8400 0.3528 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8173 0.3539 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8412 0.3684 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8578 0.3556 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8618 0.3569 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8910 0.3534 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7786 0.3565 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8177 0.3499 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7906 0.3463 sec/batch
# Nearest to about: length, disturbs, census, july, than, driest, approximately, started,
# Nearest to be: that, a, is, as, are, to, which, this,
# Nearest to been: has, most, had, flavors, eschews, although, suggested, apg,
# Nearest to d: b, composer, keenan, fran, roxanne, suvorov, monegasque, chronicon,
# Nearest to may: or, of, be, every, can, initiates, they, as,
# Nearest to into: the, first, through, which, part, to, separate, south,
# Nearest to used: usage, refer, uses, purposes, invented, as, or, term,
# Nearest to such: these, are, also, all, as, or, of, even,
# Nearest to police: lakeview, witness, crime, loria, extradited, interceptors, cardozo, gendarmerie,
# Nearest to discovered: uniformitarianism, found, piccard, bombarding, cramps, logarithmic, clear, important,
# Nearest to brother: sister, sepulveda, mszp, anoint, sturm, spends, conte, housework,
# Nearest to mathematics: mathematicians, loeb, calculus, mathematical, kummer, calculations, sindh, neopaganism,
# Nearest to hold: tinkering, socks, hyped, bent, stacked, fateh, installations, prescott,
# Nearest to square: sq, malmesbury, jharkhand, louder, face, jail, coordinates, greeted,
# Nearest to additional: repetitive, stresses, jiao, functionally, canceled, single, garner, printings,
# Nearest to bbc: links, day, june, external, skit, holidays, sek, ghat,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7778 0.3714 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8393 0.3624 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8718 0.3560 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8277 0.3470 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8352 0.3440 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8914 0.3383 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8334 0.3446 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8183 0.3439 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8401 0.3479 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8239 0.3530 sec/batch
# Nearest to about: disturbs, census, length, july, driest, viewer, started, than,
# Nearest to be: that, which, is, a, as, to, some, smaller,
# Nearest to been: has, had, most, although, apg, suggested, mitochondrial, included,
# Nearest to d: b, composer, keenan, fran, roxanne, biggs, suvorov, chronicon,
# Nearest to may: or, of, initiates, every, be, as, this, can,
# Nearest to into: first, through, the, which, but, part, to, separate,
# Nearest to used: usage, refer, uses, or, invented, as, which, purposes,
# Nearest to such: also, these, are, all, as, or, even, tartar,
# Nearest to police: lakeview, crime, loria, extradited, witness, interceptors, case, cardozo,
# Nearest to discovered: uniformitarianism, found, piccard, cramps, logarithmic, bombarding, clear, protectress,
# Nearest to brother: sister, sepulveda, mszp, anoint, sturm, son, daughter, conte,
# Nearest to mathematics: mathematicians, loeb, calculus, kummer, phd, alarming, mathematical, euclid,
# Nearest to hold: tinkering, hyped, socks, bent, compromising, stacked, reisman, prescott,
# Nearest to square: sq, malmesbury, louder, jharkhand, greeted, face, orbison, jail,
# Nearest to additional: repetitive, stresses, jiao, canceled, functionally, garner, authorisation, similar,
# Nearest to bbc: links, skit, day, june, external, aired, sek, ghat,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8375 0.3453 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8583 0.3438 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8161 0.3447 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8299 0.3463 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8672 0.3480 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8452 0.3527 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8192 0.3492 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8579 0.3438 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8021 0.3406 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8259 0.3380 sec/batch
# Nearest to about: length, july, census, disturbs, than, driest, more, that,
# Nearest to be: that, a, as, the, is, this, to, which,
# Nearest to been: has, had, most, although, surviving, was, however, suggested,
# Nearest to d: b, keenan, composer, roxanne, biggs, fran, withered, suvorov,
# Nearest to may: or, of, every, be, as, initiates, this, they,
# Nearest to into: the, through, first, which, to, but, part, as,
# Nearest to used: usage, refer, as, or, uses, is, which, the,
# Nearest to such: also, these, are, as, all, or, of, tartar,
# Nearest to police: lakeview, interceptors, crime, loria, witness, department, extradited, cardozo,
# Nearest to discovered: uniformitarianism, found, piccard, cramps, bombarding, logarithmic, clear, cristofano,
# Nearest to brother: sister, sepulveda, anoint, mszp, sturm, son, spends, daughter,
# Nearest to mathematics: mathematicians, loeb, sindh, neopaganism, mathematical, calculus, abhidhamma, alarming,
# Nearest to hold: hyped, tinkering, bent, socks, prescott, fateh, reisman, installations,
# Nearest to square: sq, jharkhand, malmesbury, louder, coordinates, tuples, greeted, lemon,
# Nearest to additional: repetitive, stresses, functionally, canceled, jiao, single, garner, with,
# Nearest to bbc: links, skit, day, external, aired, june, sek, iba,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8268 0.3538 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8357 0.3393 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9370 0.3421 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8815 0.3498 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.9125 0.3540 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7868 0.3388 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7710 0.3762 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8492 0.3541 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7398 0.3562 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8453 0.3485 sec/batch
# Nearest to about: length, july, census, driest, disturbs, than, viewer, approximately,
# Nearest to be: that, is, a, as, some, which, smaller, to,
# Nearest to been: has, most, although, had, mitochondrial, suggested, surviving, eschews,
# Nearest to d: b, composer, roxanne, keenan, suvorov, fran, biggs, menuhin,
# Nearest to may: or, of, every, iau, they, initiates, can, be,
# Nearest to into: the, through, first, part, which, to, but, separate,
# Nearest to used: usage, refer, or, uses, invented, as, is, purposes,
# Nearest to such: these, also, are, tartar, as, or, all, many,
# Nearest to police: lakeview, crime, interceptors, department, loria, witness, cardozo, extradited,
# Nearest to discovered: uniformitarianism, found, piccard, cramps, bombarding, logarithmic, clear, protectress,
# Nearest to brother: sister, sepulveda, mszp, sturm, anoint, antics, spends, son,
# Nearest to mathematics: mathematicians, mathematical, neopaganism, calculus, loeb, sindh, abhidhamma, phd,
# Nearest to hold: socks, tinkering, bent, hyped, reisman, prescott, installations, compromising,
# Nearest to square: sq, jharkhand, malmesbury, louder, jail, greeted, tora, face,
# Nearest to additional: repetitive, functionally, stresses, jiao, canceled, libyan, garner, legation,
# Nearest to bbc: links, day, external, skit, june, holidays, peckinpah, sek,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8569 0.3529 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8324 0.3458 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
